# %%
# Create API of ML model using flask

'''
This code takes the JSON data while POST request an performs the prediction using loaded model and returns
the results in JSON format.
'''
# Import libraries
import numpy as np
from flask import Flask, request, jsonify
import pickle

app = Flask(__name__)

# Load the model
model = pickle.load(open('model1.pkl','rb'))

@app.route('/api',methods=['POST'])
def predict():
    # Get the data from the POST request.
    data = request.get_json(force=True)

    # Make prediction using model loaded from disk as per the data.
    prediction = model.predict([[np.array(data['exp'])]])

    # Take the first value of prediction
    output = prediction[0]

    return jsonify(output)

if __name__ == '__main__':
    try:
         app.run(port=5000, debug=True)
    except:
        print("Server is exited unexpectedly. Please contact server admin.")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with stat
# Server is exited unexpectedly. Please contact server admin.

# %%
import pandas as pd
pd.read_csv("") # csv file
pd.read_table("") #  Tsv file (table formate file)
pd.read_excel("")
pd.read_sql(query,connection_object)
pd.read_json(json_string)
pd.read_html(url)
pd.read_clipboard()
pd.DataFrame(dict)
#create Test object
pd.DataFrame(np.random.rand(20,5))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-36b228e28433> in <module>()
#       1 import pandas as pd
# ----> 2 pd.read_csv("") # csv file
#       3 pd.read_table("") #  Tsv file (table formate file)
#       4 pd.read_excel("")
#       5 pd.read_sql(query,connection_object)
#
# ~\.conda\envs\DL_envs\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\.conda\envs\DL_envs\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\.conda\envs\DL_envs\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\.conda\envs\DL_envs\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\.conda\envs\DL_envs\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1904         kwds["usecols"] = self.usecols
#    1905
# -> 1906         self._reader = parsers.TextReader(src, **kwds)
#    1907         self.unnamed_cols = self._reader.unnamed_cols
#    1908
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'' does not exist: b''

# %%
pd.DataFrame(np.random.rand(20,5))
# Out:
#            0         1         2         3         4
# 0   0.584157  0.858630  0.360538  0.119161  0.192523
# 1   0.051654  0.333663  0.947794  0.182287  0.251808
# 2   0.763734  0.493546  0.107039  0.360865  0.762067
# 3   0.121571  0.881049  0.396968  0.489179  0.883197
# 4   0.159339  0.526577  0.336661  0.851978  0.253540
# 5   0.769209  0.359226  0.276168  0.992445  0.250195
# 6   0.317271  0.520131  0.890732  0.359618  0.765212
# 7   0.144081  0.939347  0.187544  0.717334  0.141166
# 8   0.446497  0.024260  0.696250  0.266432  0.367124
# 9   0.393287  0.649924  0.934148  0.141303  0.259588
# 10  0.135811  0.624354  0.898744  0.693574  0.616137
# 11  0.238654  0.074182  0.090115  0.646751  0.021462
# 12  0.692702  0.293203  0.616211  0.306513  0.700375
# 13  0.194392  0.636200  0.037617  0.060675  0.461304
# 14  0.806200  0.571448  0.512890  0.527012  0.077143
# 15  0.032506  0.089349  0.152584  0.026958  0.980188
# 16  0.991029  0.898955  0.471542  0.015245  0.198082
# 17  0.570517  0.087430  0.043862  0.188256  0.924934
# 18  0.587771  0.765783  0.591735  0.356256  0.221355
# 19  0.618007  0.881593  0.060010  0.416138  0.053942

# %%
import pandas as pd
pd.series(my_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-e1e9bcd94e2a> in <module>()
#       1 import pandas as pd
# ----> 2 pd.series(my_list)
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
import pandas as pd
df.index=pd.date_range(1900/1/30,periods = df.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1b0a0a6f4d4b> in <module>()
#       1 import pandas as pd
# ----> 2 df.index=pd.date_range(1900/1/30,periods = df.shape[0])
#
# NameError: name 'df' is not defined
